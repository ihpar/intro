# %%
3 + 2
# Out:
# 5

# %%
3 + 5 + 7
# Out:
# 15

# %%
3 - 5
# Out:
# -2

# %%
17.5 + 2.75
# Out:
# 20.25

# %%
# yorum, comment
(12 - 3) + (12 - 12)  # 9 + 0
# Out:
# 9

# %%
12 * 3  # asterisk
# Out:
# 36

# %%
(9 + 3) * 3
# Out:
# 36

# %%
12 / 4
# Out:
# 3.0

# %%
13/4
# Out:
# 3.25

# %%
10/3
# Out:
# 3.3333333333333335

# %%
2 ** 3
# Out:
# 8

# %%
3 ** 4
# Out:
# 81

# %%
13 // 4
# Out:
# 3

# %%
13 % 4
# Out:
# 1

# %%
12 % 4
# Out:
# 0

# %%
# +, -, *, /, **, //, %

# %%
12 + 3 * 2
# Out:
# 18

# %%
3 ** 2 * 5 ** 2
# Out:
# 225

# %%
(3 ** 2) * (5 ** 2)
# Out:
# 225

# %%
12 ** 2 - 10 ** 2 / 5 ** 2 - 3 ** 2
# Out:
# 131.0

# %%
(12 ** 2 - 10 ** 2) / (5 ** 2 - 3 ** 2)
# Out:
# 2.75

# %%
((12 ** 2) - (10 ** 2)) / ((5 ** 2) - (3 ** 2))
# Out:
# 2.75

# %%
3+5
# Out:
# 8

# %%
(3+5)
# Out:
# 8

# %%
(((3+5)))
# Out:
# 8

# %%
(2025 - 2005) * 365.25
# Out:
# 7305.0

# %%
2025 - 2005 * 365.25
# Out:
# -730301.25

# %%
type(3) # int - integer
# Out:
# int

# %%
type(3.97)
# Out:
# float

# %%
type(12/3)
# Out:
# float

# %%
type(12//3)
# Out:
# int

# %%
print(3+5)
# Out:
# 8

# %%
3+5
# Out:
# 8

# %%
3+5
5*3
7-7
# Out:
# 0

# %%
print(3+5)
print(5*3)
print(7-7)
# Out:
# 8
# 15
# 0

# %%
print(5, 3 + 3, 12 * 4)
# Out:
# 5 6 48

# %%
"hey, naber?"
# Out:
# 'hey, naber?'

# %%
type("hey, naber?") # string
# Out:
# str

# %%
type("hey, naber? 123") # string
# Out:
# str

# %%
type(123)
# Out:
# int

# %%
type("123")
# Out:
# str

# %%
"Hey" + "naber?"
# Out:
# 'Heynaber?'

# %%
"Hey " + "naber?"
# Out:
# 'Hey naber?'

# %%
"Hey" + " " + "naber?"
# Out:
# 'Hey naber?'

# %%
"Hey " - "naber?"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 "Hey " - "naber?"
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
"a" * "b"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 "a" * "b"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
"a" * 3
# Out:
# 'aaa'

# %%
"aaa" / 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 "aaa" / 3
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
"a@b.com"
# Out:
# 'a@b.com'

# %%
a@b.com
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 a@b.com
#
# NameError: name 'a' is not defined

# %%
hey
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 hey
#
# NameError: name 'hey' is not defined

# %%
"hey"
# Out:
# 'hey'

# %%
# değişkenler - variables

# %%
a = 3
print(a)
# Out:
# 3

# %%
a = 3
print(a)
print("a")
print(type(a))
# Out:
# 3
# a
# <class 'int'>

# %%
a = 5
print(a)
b = 2 * a
a = 2 * b
print(a, b)
# Out:
# 5
# 20 10

# %%
x = 5
x = x + 1
y = 2 * x
print(x, y)
# Out:
# 6 12

# %%
ilk_sayi = 5
ikinci_sayi = 7

sonuc = ilk_sayi + ikinci_sayi
print(sonuc)
# Out:
# 12

# %%
_a = 4

# %%
a_ = 5

# %%
a_2 = 7

# %%
2_a = 8
# Out:
#   Cell In[65], line 1
#     2_a = 8
#      ^
# SyntaxError: invalid decimal literal

# %%
A = 5

# %%
a_b_c = 7 # snake case

# %%
benimKilomKac = 70 # camel case

# %%
ad = "ismail"
soyad = "parlak"

mesaj = ad + soyad + "naber?"
print(mesaj)
# Out:
# ismailparlaknaber?

# %%
ad = "ismail"
soyad = "parlak"

mesaj = ad + " " + soyad + " " + "naber?"
print(mesaj)
# Out:
# ismail parlak naber?

# %%
x = 4
y = x 
x = 6
print(x, y)
# Out:
# 6 4

# %%
a = 5
a = a + 1
a = a + 1
a = a + 1
a = a + 1
print(a)
# Out:
# 9
