# %%
""" 
Alıştırmalar

1 - H x W boyutlarında *'lardan oluşan içi boş dikdörtgen print ediniz. "*" * W gibi string çarpması yapmayınız. 
Örn:
H = 4, W = 6 için 
* * * * * *
*         *
*         *
* * * * * *

2 - Bir sayı listesindeki tüm elemanların karelerini alarak listeyi güncelleyiniz.
Örn: liste = [-2, 3, 1] -> liste = [4, 9, 1]

3 - Bir sayı listesindeki en büyük ve en küçük eleman arasındaki farkı bulunuz.
Örn: liste = [5, 1, 8, -3, 2] -> fark = 11

4 - Bir sayı listesinde toplamları N eden bir ikilinin bulunup bulunmadığını bulunuz.
Örn 1: N = 8, liste = [2, 1, 4, -3, 7, 0] -> sonuç = True 
        (1 + 7 = 8 olduğu için)

Örn 2: N = 8, liste = [2, 1, 4, -3, 5, 0] -> sonuç = False 
        (Bu listede toplamları 8 yapan bir sayı ikilisi yoktur)

5 - Bir matrisin simetrik olup olmadığını bulunuz.
Örn 1: 
[ [1, 3, 5],
  [3, 4, 2],
  [5, 2, 0] ] -> True

Örn 2: 
[ [1, 3, 5],
  [1, 4, 2],
  [5, 2, 0] ] -> False

6 - N faktöryeli hesaplayan faktoryel isimli fonksiyonu tanımlayınız.
Örn: faktoryel(4) -> 24

7 - Fibonacci serisindeki N. sıradaki elemanı bulan fibonacci isimli fonksiyonu tanımlayınız.
Fibonacci serisi: 1, 1, 2, 3, 5, 8, 13, 21, ...
Örn 1: fibonacci(0) -> 1
Örn 2: fibonacci(4) -> 5
Örn 3: fibonacci(8) -> 34
"""

# %%
"""
2 - Bir sayı listesindeki tüm elemanların karelerini alarak listeyi güncelleyiniz.
Örn: liste = [-2, 3, 1] -> liste = [4, 9, 1]
"""

sayilar = [-2, 3, 1, 5]
i = 0
while i < len(sayilar):
    sayilar[i] = sayilar[i] ** 2
    i += 1

print(sayilar)
# Out:
# [4, 9, 1, 25]

# %%
"""
3 - Bir sayı listesindeki en büyük ve en küçük eleman arasındaki farkı bulunuz.
Örn: liste = [5, 1, 8, -3, 2] -> fark = 11
"""

my_list = [5, 1, 8, -3, 2]
my_list.sort()
print(my_list)
print(my_list[0])
son_idx = len(my_list) - 1
print(my_list[son_idx])
fark = my_list[son_idx] - my_list[0]
print(fark)
# Out:
# [-3, 1, 2, 5, 8]
# -3
# 8
# 11

# %%
a = [1, 2, 3]
print(a[0], a[1], a[2])
print(a[-1], a[-2], a[-3])
# Out:
# 1 2 3
# 3 2 1

# %%
"""
3 - Bir sayı listesindeki en büyük ve en küçük eleman arasındaki farkı bulunuz.
Örn: liste = [5, 1, 8, -3, 2] -> fark = 11
"""

my_list = [5, 1, 8, -3, 2]
my_list.sort()
print(my_list)
print(my_list[0])
print(my_list[-1])

print(my_list[-1] - my_list[0])
# Out:
# [-3, 1, 2, 5, 8]
# -3
# 8
# 11

# %%
my_list = [4, 5, 3, 2, 7, 8]
print(my_list[2])
print(my_list[:2])  #  list slicing
print(my_list[:4])  #  list slicing
print(my_list[0:4])  #  list slicing
print(my_list[0:-1])  #  list slicing
print(my_list[2:5])  #  list slicing
print(my_list[-3:-1])  #  list slicing
# Out:
# 3
# [4, 5]
# [4, 5, 3, 2]
# [4, 5, 3, 2]
# [4, 5, 3, 2, 7]
# [3, 2, 7]
# [2, 7]

# %%
isim = "ismail hakki"
print(isim)
print(isim[1])
print(len(isim))
print(isim[:7])
print(isim[7:])
print(isim[7:-1])
print(isim[7:])
isim[0] = "a"
print(isim)
# Out:
# ismail hakki
# s
# 12
# ismail
# hakki
# hakk
# hakki
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 9
#       7 print(isim[7:-1])
#       8 print(isim[7:])
# ----> 9 isim[0] = "a"
#      10 print(isim)
#
# TypeError: 'str' object does not support item assignment

# %%
isim = "ismail hakki"
yeni_isim = "a" + isim[1:]
print(yeni_isim)
# Out:
# asmail hakki

# %%
"""
4 - Bir sayı listesinde toplamları N eden bir ikilinin bulunup bulunmadığını bulunuz.
Örn 1: N = 8, liste = [2, 1, 4, -3, 7, 0] -> sonuç = True 
        (1 + 7 = 8 olduğu için)
"""

b = [1, 7, 2]
print(5 in b)
print(2 in b)

s = "merhaba"
print("k" in s)
print("ba" in s)
# Out:
# False
# True
# False
# True

# %%
"""
4 - Bir sayı listesinde toplamları N eden bir ikilinin bulunup bulunmadığını bulunuz.
Örn 1: N = 8, liste = [2, 1, 4, -3, 7, 0] -> sonuç = True 
        (1 + 7 = 8 olduğu için)
"""

N = 8
liste = [2, 1, 4, -3, 6, 0]

cevap = False
for sayi in liste:
    fark = N - sayi
    if fark in liste:
        cevap = True
        break

print(cevap)
# Out:
# True

# %%
"""
bir listenin sıralı olup olmadığını bulunuz.
Ör: [1, 2, 5, 7] -> True
Ör: [1, 3, 2, 4] -> False
"""

my_list = [1, 3, 4, 7]
sirali = True
i = 0
while i < len(my_list) - 1:
    # print(my_list[i], my_list[i+1])
    if my_list[i] > my_list[i+1]:
        sirali = False
        break
    i += 1

print(sirali)
# Out:
# True

# %%
matris = [[1, 2], [3, 4], [5, 6]]  # 3 satır; 2 sütun. nested - yuvalı - iç içe
print(len(matris))
print(matris[0])
print(matris[1])
print(matris[2])
# Out:
# 3
# [1, 2]
# [3, 4]
# [5, 6]

# %%
matris = [
    [1, 2],
    [3, 4],
    [5, 6]
]

for el in matris:
    print(el)

for satir in matris:
    for el in satir:
        print(el)
    print("satır bitti")
# Out:
# [1, 2]
# [3, 4]
# [5, 6]
# 1
# 2
# satır bitti
# 3
# 4
# satır bitti
# 5
# 6
# satır bitti

# %%
matris = [
    [1, 2],
    [3, 4],
    [5, 6]
]

print(matris[2])
print(matris[2][1])
print(matris[0][0])
print(matris[0][1])
print(matris[1][1])
# Out:
# [5, 6]
# 6
# 1
# 2
# 4

# %%
matris = [
    [1, 2],
    [3, 4],
    [5, 6]
]

i = 0
while i < len(matris):
    # print(matris[i])
    j = 0
    while j < len(matris[i]):
        print(matris[i][j])
        j += 1
    print(f"{i} satiri bitti")
    i += 1
# Out:
# 1
# 2
# 0 satiri bitti
# 3
# 4
# 1 satiri bitti
# 5
# 6
# 2 satiri bitti

# %%
mat = [
    [1, 3, 5],
    [3, 4, 2],
    [5, 2, 0]
]

i, j = 1, 2

print(mat[i][j])
print(mat[j][i])
# Out:
# 2
# 2

# %%
my_list = [
    [1],
    [3, 5],
    ["abc", "def"],
    [9, 9, 9]
]

for row in my_list:
    for x in row:
        print(x, len(row))

print(my_list[3])
print(my_list[-1])
print(my_list[-1][-1])
# Out:
# 1 1
# 3 2
# 5 2
# abc 2
# def 2
# 9 3
# 9 3
# 9 3
# [9, 9, 9]
# [9, 9, 9]
# 9

# %%
# dictionary
# key - value pair; anahtar - değer ikilisi
a = {"ad": "ismail", "soyad": "parlak"}
print(a)
print(a["ad"])
print(a["soyad"])
# Out:
# {'ad': 'ismail', 'soyad': 'parlak'}
# ismail
# parlak

# %%
a["renk"] = "sari"
a["sayi"] = 75

print(a)
# Out:
# {'ad': 'ismail', 'soyad': 'parlak', 'renk': 'sari', 'sayi': 75}

# %%
b = {}

b["x"] = "y"
b["k"] = 55
b["adres"] = "abant izzet baysal ..."
print(b)
# Out:
# {'x': 'y', 'k': 55, 'adres': 'abant izzet baysal ...'}

# %%
print(b["adres"])
# Out:
# abant izzet baysal ...

# %%
for el in b:
    print(el, b[el])
# Out:
# x y
# k 55
# adres abant izzet baysal ...

# %%
for anahtar, deger in b.items():
    print(anahtar, deger)
# Out:
# x y
# k 55
# adres abant izzet baysal ...

# %%
ogrenciler = []

ilk_ogrenci = {"ad": "abc", "ort": 2.5,
               "tel": 123456789, "dersler": ["mat", "tr"]}
ikinci_ogrenci = {"ad": "def", "ort": 3.5,
                  "tel": 223456789, "dersler": ["sos", "fen", "tar"]}
ucuncu_ogrenci = {"ad": "ghi", "ort": 1.5,
                  "tel": 323456789, "dersler": ["bilg", "py"]}

ogrenciler.append(ilk_ogrenci)
ogrenciler.append(ikinci_ogrenci)
ogrenciler.append(ucuncu_ogrenci)

print(ogrenciler)
# Out:
# [{'ad': 'abc', 'ort': 2.5, 'tel': 123456789, 'dersler': ['mat', 'tr']}, {'ad': 'def', 'ort': 3.5, 'tel': 223456789, 'dersler': ['sos', 'fen', 'tar']}, {'ad': 'ghi', 'ort': 1.5, 'tel': 323456789, 'dersler': ['bilg', 'py']}]

# %%
print(ogrenciler[0])
print(ogrenciler[2])
print(ogrenciler[0]["ort"])
# Out:
# {'ad': 'abc', 'ort': 2.5, 'tel': 123456789, 'dersler': ['mat', 'tr']}
# {'ad': 'ghi', 'ort': 1.5, 'tel': 323456789, 'dersler': ['bilg', 'py']}
# 2.5

# %%
for og in ogrenciler:
    print(og["ad"], og["ort"], og["dersler"][0])
# Out:
# abc 2.5 mat
# def 3.5 sos
# ghi 1.5 bilg
